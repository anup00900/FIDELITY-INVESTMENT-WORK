# %%
ls
# Out:
# AGAIN/
# DATASET/
# GAIN_Implementation.ipynb
# GAT_Experiment_Rachna_Mam_Full_Fidelity_Dataset-Data Loader Exp.ipynb
# GAT_Experiment_Rachna_Mam_Full_Fidelity_Dataset-Data Loader.ipynb
# GAT_Experiment_Rachna_Mam_Full_Fidelity_Dataset.ipynb
# GAT_INDUCTIVE_NEW_APPROACH.ipynb
# GAT_Rachna_Mam_Full_Fidelity_Dataset-Data Loader-Modification.ipynb
# GAT Tensorflow-pytorch Implementation(May-18-2023) .ipynb
# lost+found/
# Model/
# VA_Final_Final_Sep08Ankit (Oct 8).xlsx

# %%
cd AGAIN
# Out:
# /home/ec2-user/SageMaker/AGAIN

# %%
ls
# Out:
# AGAIN.py  GAT_inductive/  LICENSE  models.py    nn_modules.py  problem.py
# data/     helpers.py      lr.py    model_test/  parse_args.py  README.md

# %%
cd GAT_inductive
# Out:
# /home/ec2-user/SageMaker/AGAIN/GAT_inductive

# %%
ls
# Out:
# blogcatalog.mat  models.py         readme.md      train.py
# layers.py        planetoid_induc/  train_blog.py  utils.py

# %%
# !python train.py
# Out:
# got
# len after sampling 10000
# Original Training set size: 5600
# Original Test set size: 1400
# Average Length: 7.801428571428572
# word_list 2284
# labels and sentences length 7000 7000
# adj.shape torch.Size([9284, 9284]) adj_train.shape torch.Size([9284, 9284]) features.shape torch.Size([9284, 2284]) labels.shape torch.Size([9284, 193])
# idx_train, idx_val, idx_test, idx_tot tensor([   0,    1,    2,  ..., 5597, 5598, 5599]) torch.Size([5040]) torch.Size([560]) torch.Size([5600]) torch.Size([7000])
# output_s.shape train torch.Size([9284, 193])
# output_s.shape test torch.Size([9284, 193])
# epoch 000 | train loss 5.2627 | train micro-F1 0.0003 | train macro-F1 0.0003
# test loss 5.2372 | test micro-F1 0.0261 | test macro-F1 0.0261
# output_s.shape train torch.Size([9284, 193])
# output_s.shape test torch.Size([9284, 193])
# epoch 001 | train loss 5.2389 | train micro-F1 0.0180 | train macro-F1 0.0180
# test loss 5.2134 | test micro-F1 0.0416 | test macro-F1 0.0416
# ...
