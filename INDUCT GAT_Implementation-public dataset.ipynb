# %%
ls
# Out:
# AGAIN/
# DATASET/
# GAIN_Implementation.ipynb
# GAIN_Implementation-PART-2.ipynb
# GAT_Experiment_Rachna_Mam_Full_Fidelity_Dataset-Data Loader Exp.ipynb
# GAT_Experiment_Rachna_Mam_Full_Fidelity_Dataset-Data Loader.ipynb
# GAT_Experiment_Rachna_Mam_Full_Fidelity_Dataset.ipynb
# GAT_INDUCTIVE_NEW_APPROACH.ipynb
# GAT_Rachna_Mam_Full_Fidelity_Dataset-Data Loader-Modification.ipynb
# GAT Tensorflow-pytorch Implementation(May-18-2023) .ipynb
# lost+found/
# Model/

# %%
cd AGAIN
# Out:
# /home/ec2-user/SageMaker/AGAIN

# %%
ls
# Out:
# AGAIN.py  GAT_inductive/  LICENSE  models.py    nn_modules.py  problem.py
# data/     helpers.py      lr.py    model_test/  parse_args.py  README.md

# %%
cd GAT_inductive
# Out:
# /home/ec2-user/SageMaker/AGAIN/GAT_inductive

# %%
ls
# Out:
# blogcatalog.mat   __pycache__/   utils.py
# layers.py         readme.md      VA_Final_Final_Sep08Ankit (Oct 8).xlsx
# models.py         train_blog.py
# planetoid_induc/  train.py

# %%
# !python train.py
# Out:
# got
# len after sampling 10000
# Original Training set size: 7000
# Original Test set size: 3000
# Average Length: 7.817857142857143
# labels and sentences length 10000 10000
# adj.shape torch.Size([12456, 12456]) adj_train.shape torch.Size([12456, 12456]) features.shape torch.Size([12456, 2456]) labels.shape torch.Size([12456, 193])
# idx_train, idx_val, idx_test, idx_tot tensor([   0,    1,    2,  ..., 6996, 6997, 6998]) tensor([   7,   23,   32,   33,   40,   50,   52,   53,   54,   74,   87,   89,
#           90,   97,  103,  114,  117,  124,  149,  156,  169,  196,  210,  226,
#          237,  272,  277,  309,  314,  327,  330,  331,  333,  335,  341,  345,
#          356,  357,  358,  381,  384,  410,  420,  441,  455,  456,  465,  467,
#          498,  509,  526,  535,  543,  549,  568,  591,  595,  613,  615,  628,
#          636,  648,  659,  679,  701,  707,  726,  734,  739,  768,  778,  787,
# ...
